# %%
cd /content/drive/MyDrive/HAI
# Out:
# /content/drive/MyDrive/HAI

# %%
import src.methods_evaluation as me
import src.experience as exp
import src.MOE_M as moe_run
import json
from matplotlib import pyplot as plt

# %%
Config_Path = '/content/drive/MyDrive/HAI/config/Bnn_MOE_Config.json'
with open(Config_Path) as config_file:
    cfg = json.load(config_file)
HP = exp.create_experiments()
eval_m = moe_run.moe(cfg, HP, "datapath_RFECV")
#eval_m.models_Prepration()
# Out:
# Data Preparation Done!

# %%
history= eval_m.MOE_Run()
# Out:
# Module - RF Done!
# Module - ET Done!
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# Module - MLP Done!
# Module - LR Done!
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  Input_Ex1 (InputLayer)         [(None, 2)]          0           []
#
#  Input_EX2 (InputLayer)         [(None, 2)]          0           []
#
#  Input_EX3 (InputLayer)         [(None, 2)]          0           []
#
#  Input_EX4 (InputLayer)         [(None, 2)]          0           []
#
#  in_Data (InputLayer)           [(None, 31)]         0           []
#
#  concatenate (Concatenate)      (None, 39)           0           ['Input_Ex1[0][0]',
# ...

# %%
history= eval_m.MOE_Run()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model = tf.keras.Sequential([
tf.keras.layers.InputLayer(input_shape=(len(inputs),), name="input"),
tf.keras.layers.Dense(10, activation="relu", name="dense_1"),
tf.keras.layers.Dense(tfp.layers.MultivariateNormalTriL.params_size(
len(outputs)), activation=None, name="distribution_weights"),
tfp.layers.MultivariateNormalTriL(len(outputs), activity_regularizer=tfp.layers.KLDivergenceRegularizer(prior, weight=1/n_batches), name="output")
], name="model")

# %%
layers.Dense(10, activation="relu", name="dense_1")
layers.Dense(tfp.layers.MultivariateNormalTriL.params_size(len(outputs)), activation=None)
